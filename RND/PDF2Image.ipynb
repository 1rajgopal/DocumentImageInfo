# %%
#!pip install pdf2image
#!apt-get install -y poppler-utils
import os
import tempfile
from pdf2image import convert_from_path
 
filename = '23344556.pdf'
#print(os.path)
with tempfile.TemporaryDirectory() as path:
     images_from_path = convert_from_path(filename,200, output_folder=path, first_page =0,last_page=1)
 
base_filename  =  os.path.splitext(os.path.basename(filename))[0] + '.jpg'     
 
save_dir = 'your_saved_dir'
 
for page in images_from_path:
    page.save(os.path.join(save_dir, base_filename), 'JPEG')
# Out:
# <module 'posixpath' from '/usr/lib/python3.6/posixpath.py'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pdf2image/pdf2image.py in _page_count(pdf_path, userpw, poppler_path)
#     364         # This will throw if we are unable to get page count
# --> 365         return int(re.search(r"Pages:\s+(\d+)", out.decode("utf8", "ignore")).group(1))
#     366     except:
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# <ipython-input-61-f5e988a9f5e7> in <module>()
#       6 print(os.path)
#       7 with tempfile.TemporaryDirectory() as path:
# ----> 8      images_from_path = convert_from_path(filename,200, output_folder=path, first_page =0,last_page=1)
#       9
#      10 base_filename  =  os.path.splitext(os.path.basename(filename))[0] + '.jpg'
#
# /usr/local/lib/python3.6/dist-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only)
#      80         poppler_path = poppler_path.as_posix()
#      81
# ---> 82     page_count = _page_count(pdf_path, userpw, poppler_path=poppler_path)
#      83
#      84     # We start by getting the output format, the buffer processing function and if we need pdftocairo
#
# /usr/local/lib/python3.6/dist-packages/pdf2image/pdf2image.py in _page_count(pdf_path, userpw, poppler_path)
#     366     except:
#     367         raise PDFPageCountError(
# --> 368             "Unable to get page count. %s" % err.decode("utf8", "ignore")
#     369         )
#     370
#
# PDFPageCountError: Unable to get page count. I/O Error: Couldn't open file '23344556.pdf': No such file or directory.

# %%
import os
from pdf2image import convert_from_path

pdf_dir = 'your_source'
#print(os.curdir)
#print(os.listdir())
#os.chdir(pdf_dir)

for pdf_file in os.listdir():

    if pdf_file.endswith(".pdf"):

        pages = convert_from_path(pdf_file, 300)
        pdf_file = pdf_file[:-4]

        for page in pages:

          page.save("%s-page%d.jpg" % (pdf_file,pages.index(page)), "JPEG")
# Out:
# .
